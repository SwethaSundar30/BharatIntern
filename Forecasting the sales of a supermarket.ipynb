# %% [markdown]
# # Forecasting the sales of a supermarket

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import  RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from pandas_profiling import ProfileReport
# Out:
# C:\Users\sweth\AppData\Local\Temp\ipykernel_18168\1822037861.py:9: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
df=pd.read_csv(r"C:\Users\sweth\OneDrive\Pictures\Desktop\Test Jupyter\train.csv")

# %%
df.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year
# 0     6.800000         0.037490   48.6034                       2004  \
# 1    15.600000         0.172597  114.8518                       1997
# 2    12.911575         0.054721  107.8254                       1985
# 3    11.800000         0.098312   81.4618                       1998
# 4    17.850000         0.046600  125.1388                       2004
#
#    Item_Outlet_Sales  Item_Fat_Content_LF  Item_Fat_Content_Low Fat
# 0           291.6204                    0                         1  \
# 1          2163.1842                    0                         1
# 2          2387.5588                    0                         1
# 3           161.1236                    0                         1
# 4          1981.4208                    0                         0
#
#    Item_Fat_Content_Regular  Item_Fat_Content_low fat  Item_Fat_Content_reg
# ...

# %%
df.describe(include='all')
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  1364.000000      1364.000000  1364.000000                1364.000000  \
# mean     12.954350         0.065986   143.341417                1997.846041
# std       4.253846         0.052407    62.726611                   8.247887
# min       4.590000         0.000000    32.855800                1985.000000
# 25%       9.473750         0.026369    95.002800                1987.000000
# 50%      12.911575         0.053527   144.695700                1999.000000
# 75%      16.200000         0.094024   188.064800                2004.000000
# max      21.250000         0.321115   266.688400                2009.000000
#
#        Item_Outlet_Sales  Item_Fat_Content_LF  Item_Fat_Content_Low Fat
# count        1364.000000          1364.000000               1364.000000  \
# mean         2237.647877             0.040323                  0.592375
# ...

# %%
round(df.isnull().mean()*100,2)
# Out:
# Item_Weight                        0.0
# Item_Visibility                    0.0
# Item_MRP                           0.0
# Outlet_Establishment_Year          0.0
# Item_Outlet_Sales                  0.0
# Item_Fat_Content_LF                0.0
# Item_Fat_Content_Low Fat           0.0
# Item_Fat_Content_Regular           0.0
# Item_Fat_Content_low fat           0.0
# Item_Fat_Content_reg               0.0
# Item_Type_Baking Goods             0.0
# Item_Type_Breads                   0.0
# Item_Type_Breakfast                0.0
# Item_Type_Canned                   0.0
# Item_Type_Dairy                    0.0
# Item_Type_Frozen Foods             0.0
# Item_Type_Fruits and Vegetables    0.0
# Item_Type_Hard Drinks              0.0
# Item_Type_Health and Hygiene       0.0
# Item_Type_Household                0.0
# Item_Type_Meat                     0.0
# Item_Type_Others                   0.0
# Item_Type_Seafood                  0.0
# Item_Type_Snack Foods              0.0
# ...

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.heatmap(df.corr(method='spearman'), annot=False, linewidths=0.7, ax=ax, fmt='.3f',cmap=sns.diverging_palette(250,12,as_cmap=True))
fig.suptitle('Heat Map')
# Out:
# Text(0.5, 0.98, 'Heat Map')

# %%
train_x = df.drop(columns=['Item_Outlet_Sales'],axis=1) 
train_y = df['Item_Outlet_Sales'] #Target

# %%
modelLinear=LinearRegression()
modelLinear.fit(train_x,train_y)
print('\nCoefficient of model :', modelLinear.coef_)
print('\nIntercept of model',modelLinear.intercept_)
# Out:
# Coefficient of model : [-3.84197604e+00  9.83065945e+00  1.61711856e+01  6.09197622e+01
#  -8.64161561e+01  1.23593376e+02  2.34714039e+02 -2.44597425e+02
#  -2.72938329e+01 -8.09611456e+00 -3.01147840e+02  1.70727611e+02
#  -5.40194744e+01  7.34248834e+01  1.70313375e+00 -5.07701615e+01
#   1.63553657e+02 -5.85286125e+01  1.04913492e+02 -6.01944874e+01
#   1.98948206e+02 -1.40959023e+02  1.19426257e+02  2.66382669e+01
#  -1.85619792e+02  1.43925357e+03  2.16134663e+02  3.54723990e+01
#   3.54832996e+02 -5.54559635e+00 -3.49287400e+02 -1.39202954e+03
#  -2.57982359e+02 -9.59016062e+02  2.60902796e+03]
#
# Intercept of model -121926.97473298278

# %%
predict_train = modelLinear.predict(train_x)
print('\nItem_Outlet_Sales on training data',predict_train)
rmse_train = mean_squared_error(train_y,predict_train)**(0.5)
print('\nRMSE on train dataset : ', rmse_train)
# Out:
# Item_Outlet_Sales on training data [ 803.88817641 1733.98835979 3294.52154482 ...  811.16967914 2343.96927185
#  2444.98869913]
#
# RMSE on train dataset :  1135.8159344155245

# %%
model_RFR = RandomForestRegressor(max_depth=5)
model_RFR.fit(train_x, train_y)
predict_train = model_RFR.predict(train_x)
print('RMSE on train data: ', mean_squared_error(train_y, predict_train)**(0.5))
# Out:
# RMSE on train data:  1024.6491157644443
